# %%
import numpy as np
import sys

# %%
e = -100000
X1 = np.linspace(0, 3.0,100)
X2 = np.linspace(0, 1.5, 100)
N1 = X1.shape[0]
N2 = X2.shape[0]
U = np.linspace(-10.0, 10.0, 100)
nU = U.shape[0]

J = 1.625103
m = 0.506
M0 = 0.434
L0 = 0.305
R0 = 0.023
B0 = 16.25163
L = 0.0250103
R = 5.0
Kt = 0.90
Kb = 0.90
g = 9.8
M = J + m*L0*L0/3.0 + M0*L0*L0 + 2*M0*R0*R0/5/Kt
N = m*L0*g/2.0 + M0*L0*g/Kt
B = B0/Kt


class SingleLinkManipulatorEnv:
    def _ns(self, x1, x2, a):
        a+=np.random.normal(0, 0.1)
        x3 = (a-Kb*x2)/R
        x1dot = x2
        x2dot = -(N/M)*np.sin(x1) - (B/M)*x2 + (x3/M)
        x1p = x1 + 0.1*x1dot
        x2p = x2 + 0.1*x2dot
        return (x1p, x2p)

    def _quantize(self, x1p, x2p):
        INF = 100000
        d1 = d2 = INF
        x1pd = x2pd = 0
        for i in range(N1):
            if np.abs(x1p - X1[i]) < d1:
                d1 = np.abs(x1p - X1[i])
                x1pd = i
        for j in range(N2):
            if np.abs(x2p - X2[j]) < d2:
                d2 = np.abs(x2p - X2[j])
                x2pd = j
        return (x1pd, x2pd)

    def _reward(self, x1, x2):
        return -np.abs(x1-np.pi/6.0) - np.abs(x2)

    def __init__(self, shape=[N1, N2]):
        self.shape = shape
        nS = np.prod(shape)
        nA = nU

        Y_MAX = shape[0]
        X_MAX = shape[1]

        P = {}
        grid = np.arange(nS).reshape(shape)
        it = np.nditer(grid, flags=['multi_index'])

        while not it.finished:
            s = it.iterindex
            x, y = it.multi_index
            # print("x: " + str(x))
            # print("y: " + str(y))
            P[s] = {a: [] for a in range(nA)}

            for a in range(nU):
                x1 = X1[x]
                x2 = X2[y]
                x1p, x2p = self._ns(x1, x2, a)
                # returns index wrt X1 and X2
                x1pd, x2pd = self._quantize(x1p, x2p)
                # calculate x1pd and x2pd as a flat array
                ns = (x1pd)*X_MAX + (x2pd)
                
                P[s][a] = [(1.0, ns, self._reward(X1[x1pd], X2[x2pd]), False)]
            it.iternext()
        self.P = P
        self.nS = nS
        self.nA = nA

# %%
def value_iteration(env, gamma, eps):
  """
  Arguments:


  env: custom class having the following parameters
    env.P[s][a] is list of transition tuples (p, s_prime, r, terminal)
    env.nS denotes number of states in the env
    env.nA denotes number of actions in the env
  gamma: discount factor
  eps: error epsilon
  
  Returns:

  A tuple (policy, V)
  policy is optimal
  Shape of policy is [S,A]
  V is value function for optimal policy
  """

  def one_step_lookahead(s, V, log = False):
    A = np.zeros(env.nA)
    for a in range(env.nA):
      for p, s_prime, r, terminal in env.P[s][a]:
        if log:
          print(env.P[s][a])
        A[a] += p*(r + gamma * V[s_prime])
    return A
  
  # init v0
  V = np.zeros(env.nS)
  n_iter = 1
  while n_iter <= 200:
    delV = 0
    # full backup for each state
    for s in range(env.nS):
      # find best action at t+1
      A = one_step_lookahead(s, V)
      best_action_value = np.max(A)

      # calc delta and update value function
      delV = max(delV, np.abs(best_action_value - V[s]))
      V[s] = best_action_value
    # print("Value function at iteration: " + str(n_iter)+ ":")
    # print(V.reshape(env.shape))
    n_iter+=1
    # if delV < eps:
    #   break


  policy = np.zeros([env.nS, env.nA])
  # print("Policy Shape: ")
  # print(policy)
  for s in range(env.nS):
    # find best action for state using t+1
    A = one_step_lookahead(s, V, False)
    best_action = np.argmax(A)
    # print("State: "+str(s)+ " => Action: ", end=" ")
    # print(A)
    # greedily take best action
    policy[s, best_action] = 1.0

  return policy, V

# %%
env = SingleLinkManipulatorEnv()

# %%
policy, v = value_iteration(env, 0.99, 0.00001)
# print("Policy")
# print(np.reshape(np.argmax(policy, axis = 1), env.shape))
# print("\nValue Function")
# print(v.reshape(env.shape))
# print(policy)
policy = np.reshape(np.argmax(policy, axis = 1), env.shape)

# %%
# Creating Dataset for Training
x_train = np.array([[0.0,0.0]])
y_train = np.array([[0.0]])
for i in range(N1):
    for j in range(N2):
        x_train = np.append(x_train, np.array([[X1[i], X2[j]]]), axis=0)
        y_train = np.append(y_train, np.array([U[policy[i,j]]]))

x_train = x_train[1:]
y_train = y_train[1:]/10.0

# %%
from tensorflow import keras
import matplotlib.pyplot as plt


model = keras.Sequential([
    keras.layers.Input(shape=(2,)),
    keras.layers.Dense(50, activation='softplus'),
    keras.layers.Dense(50, activation='softplus'),
    keras.layers.Dense(1, activation='tanh'),
])

model.summary()
model.compile(
    optimizer=keras.optimizers.Adam(),  # Optimizer
    # Loss function to minimize
    loss=keras.losses.MeanSquaredError(),
    # List of metrics to monitor
    metrics=[keras.metrics.MeanSquaredError()],
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                150
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=100,
    epochs=100,
)
f = plt.figure()
# f.set_figwidth(6)
# f.set_figheight(6)
f.set_size_inches(3.25, 3.25)
plt.plot(history.history['loss'], color="black")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.tight_layout(pad=2)
plt.grid(True)
plt.savefig("gaussian/ann_loss.png", format="png", dpi=300)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 1ms/step - loss: 0.3005 - mean_squared_error: 0.3005
# Epoch 2/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2037 - mean_squared_error: 0.2037
# Epoch 3/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1115 - mean_squared_error: 0.1115
# Epoch 4/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0577 - mean_squared_error: 0.0577
# Epoch 5/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0321 - mean_squared_error: 0.0321
# Epoch 6/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 7/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 8/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 9/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 10/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 11/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 12/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 13/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 14/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 15/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 16/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 17/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 18/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 19/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 20/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 21/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 22/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 23/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 24/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 25/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 26/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 27/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 28/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 29/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 30/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 31/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 32/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 33/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 34/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 35/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 36/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 37/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 38/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 39/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 40/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 41/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 42/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 43/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 44/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 45/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 46/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 47/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 48/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 49/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 50/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 51/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 52/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 53/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 54/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 55/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 56/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 57/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 58/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 59/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 60/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 61/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 62/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 63/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 64/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 65/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 66/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 67/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 68/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 69/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 70/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 71/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 72/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 73/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 74/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 75/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 76/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 77/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 78/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 79/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 80/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 81/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 82/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 83/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 84/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 85/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 86/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 87/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 88/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 89/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 90/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 91/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 92/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 93/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 94/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 95/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 96/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 97/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 98/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 99/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 100/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070

# %%
rewards = np.array([])
state = [X1[0], X2[0]]
actions = np.array([])
for eps in range(200):
    act = model.predict((np.atleast_2d(state))).astype(np.float32)[0,0]
    act *=10.0
    actions = np.append(actions, act)
    s_prime = env._ns(state[0], state[1], act)
    state = s_prime
    reward = env._reward(state[0], state[1])
    rewards = np.append(rewards, reward)

f = plt.figure()

# f.set_figwidth(6)
# f.set_figheight(6)
f.set_size_inches(3.25, 3.25)

plt.xlabel("episode")
plt.ylabel("reward")
plt.plot(rewards, color="black")
plt.tight_layout(pad=1.5)
plt.grid(True)
plt.savefig("gaussian/rewards_simulation.png", format="png", dpi=300, bbox_inches='tight')
# Out:
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
from matplotlib import cm

plt.style.use('_mpl-gallery')

X1m, X2m = np.meshgrid(X1, X2)
Z = env._reward(X1m, X2m)
fig, ax = plt.subplots(1,1)
# fig.set_figheight(6)
# fig.set_figwidth(6)
f.set_size_inches(3.25, 3.25)
cp = ax.contourf(X1m, X2m, Z, cmap="Greys")
cb = fig.colorbar(cp)
ax.set_xlabel("x1")
ax.set_ylabel("x2")
cb.set_label("reward")
# ax.set_xlabel("x1", fontsize=8)
# ax.set_ylabel("x2", fontsize=8)
# ax.set_zlabel("reward", fontsize=8)
# ax.dist=15

plt.savefig("gaussian/reward_plot_over_domain.png", format="png", dpi=300, bbox_inches='tight')

# %%
f = plt.figure()
f.set_size_inches(3.25, 3.25)
plt.xlabel("episode")
plt.ylabel("action")
plt.plot(actions, color="black")
plt.tight_layout(pad=2)
plt.grid(True)
plt.savefig("gaussian/control_plot.png", format="png", dpi=300)

# %%
print(rewards[49])
print(rewards[99])
print(rewards[149])
print(rewards[199])
# Out:
# -0.2380947224595999
# -0.22307958029925762
# -0.22345514024325697
# -0.22455256770266704
